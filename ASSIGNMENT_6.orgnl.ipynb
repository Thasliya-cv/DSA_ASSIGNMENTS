# %% [markdown]
# # REGRESSION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('car_age_price.csv')
df
# Out:
#      Year   Price
# 0    2018  465000
# 1    2019  755000
# 2    2019  700000
# 3    2018  465000
# 4    2018  465000
# ..    ...     ...
# 107  2016  375000
# 108  2014  300000
# 109  2015  425000
# 110  2016  420000
# 111  2015  425000
#
# [112 rows x 2 columns]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(x='Year',y='Price',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
x=df['Year'].values.reshape(-1,1)
y=df["Price"].values.reshape(-1,1)

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y)

# %%
lin=LinearRegression()

# %%
lin_model=lin.fit(x,y)
lin_pred=lin_model.predict([[2022]])
lin_pred
# Out:
# array([[715488.07850975]])

# %%
plt.scatter(x,y,color='blue',label='Datas')
plt.plot(x, lin.predict(x), color='red', label='Regression Line')
plt.scatter(2022,lin_pred,color='green',label='2022 Prediction')
plt.xlabel('Year')
plt.ylabel('Price')
plt.legend()
plt.show()
