# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1=df.select_dtypes(float)
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### FUNCTION TRANSFORMERS

# %% [markdown]
# #### Log transform

# %%
from sklearn.preprocessing import FunctionTransformer
log=FunctionTransformer(func=np.log1p)
log_transform=log.fit_transform(df1)
log_transform.hist()
log_transform.skew()
# Out:
# sepal_length    0.082584
# sepal_width    -0.003868
# petal_length   -0.522090
# petal_width    -0.410450
# dtype: float64

# %% [markdown]
# #### Square transform

# %%
from sklearn.preprocessing import FunctionTransformer
sqr=FunctionTransformer(func=np.square)
sqr_transform=sqr.fit_transform(df1)
sqr_transform.hist()
sqr_transform.skew()
# Out:
# sepal_length    0.598173
# sepal_width     0.783759
# petal_length    0.186769
# petal_width     0.586110
# dtype: float64

# %% [markdown]
# #### square root transform

# %%
from sklearn.preprocessing import FunctionTransformer
sqrt=FunctionTransformer(func=np.sqrt)
sqrt_transform=sqrt.fit_transform(df1)
sqrt_transform.hist()
sqrt_transform.skew()
# Out:
# sepal_length    0.177853
# sepal_width     0.109010
# petal_length   -0.448643
# petal_width    -0.441159
# dtype: float64

# %% [markdown]
# #### sine transform

# %%
from sklearn.preprocessing import FunctionTransformer
sine=FunctionTransformer(func=np.sin)
sine_transform=sine.fit_transform(df1)
sine_transform.hist()
sine_transform.skew()
# Out:
# sepal_length    0.595210
# sepal_width    -0.318212
# petal_length    0.429986
# petal_width    -0.631687
# dtype: float64

# %% [markdown]
# #### cosine transform

# %%
from sklearn.preprocessing import FunctionTransformer
cosine=FunctionTransformer(func=np.cos)
cosine_transform=cosine.fit_transform(df1)
cosine_transform.hist()
cosine_transform.skew()
# Out:
# sepal_length   -0.859045
# sepal_width     2.101143
# petal_length   -0.162698
# petal_width    -0.131528
# dtype: float64

# %% [markdown]
# #### Tan transform

# %%
from sklearn.preprocessing import FunctionTransformer
tan=FunctionTransformer(func=np.tan)
tan_transform=tan.fit_transform(df1)
tan_transform.hist()
tan_transform.skew()
# Out:
# sepal_length    6.817341
# sepal_width     0.908218
# petal_length    2.663179
# petal_width    -2.308617
# dtype: float64

# %% [markdown]
# ### POWER TRANSFORMER

# %% [markdown]
# #### box cox transform

# %%
from sklearn.preprocessing import PowerTransformer
boxcox=PowerTransformer(method='box-cox')
boxcox_transform=boxcox.fit_transform(df1)
boxcox_transform=pd.DataFrame(boxcox_transform)
boxcox_transform.hist()
boxcox_transform.skew()
# Out:
# 0    0.005205
# 1    0.001323
# 2   -0.300740
# 3   -0.347301
# dtype: float64

# %% [markdown]
# #### yeo jhonson transform

# %%
from sklearn.preprocessing import PowerTransformer
yeo=PowerTransformer()
yeo_transform=yeo.fit_transform(df1)
yeo_transform=pd.DataFrame(yeo_transform)
yeo_transform.hist()
yeo_transform.skew()
# Out:
# 0    0.009869
# 1    0.000039
# 2   -0.246172
# 3   -0.157775
# dtype: float64

# %% [markdown]
# ### QUANTILE TRANSFORM

# %%
from sklearn.preprocessing import QuantileTransformer
Q=QuantileTransformer(output_distribution='normal')
Q_transform=Q.fit_transform(df1)
Q_transform=pd.DataFrame(Q_transform)
Q_transform.hist()
Q_transform.skew()
# Out:
# C:\Users\thasl\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2785: UserWarning: n_quantiles (1000) is greater than the total number of samples (150). n_quantiles is set to n_samples.
#   warnings.warn(
# 0   -0.017275
# 1    0.006525
# 2   -0.004640
# 3   -0.645365
# dtype: float64

# %% [markdown]
# #### ***YEO jHONSON transformer is most suitable***
